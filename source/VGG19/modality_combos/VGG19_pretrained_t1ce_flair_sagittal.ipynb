# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
# import tensorflow_addons as tfa
# from tensorflow_addons.optimizers import Lookahead
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
physical_devices # VICTORY

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(horizontal_flip = False, 
                                   vertical_flip = False,
                                   brightness_range = [0.5, 1.25],
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(horizontal_flip = False, 
                                  vertical_flip = False,
                                  rotation_range = 0,
                                  samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1ce_flair_sagittal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1ce_flair_sagittal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1ce_flair_sagittal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 6513 images belonging to 3 classes.
# Found 1855 images belonging to 3 classes.
# Found 502 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.28291008

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(50, activation = 'relu')(x)
x = Dropout(0.35)(x)
x = Dense(20, activation = 'relu')(x)
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                1254450
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 21,279,917
# Trainable params: 1,255,533
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_sagittal_t1ce_flair_3rd.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer_history.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience = 15, 
                   verbose = 1, restore_best_weights = True)

# %%
# Compile model
model.compile(Adam(lr = 1e-5),   
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 45 
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])
# maybe add argument use_multiprocessing = True

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/45
# 101/101 [==============================] - 17s 159ms/step - loss: 1.1256 - accuracy: 0.3667 - val_loss: 0.9985 - val_accuracy: 0.5882
#
# Epoch 00001: val_accuracy improved from -inf to 0.58817, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 2/45
# 101/101 [==============================] - 16s 158ms/step - loss: 1.0262 - accuracy: 0.5341 - val_loss: 0.8972 - val_accuracy: 0.6864
#
# Epoch 00002: val_accuracy improved from 0.58817 to 0.68638, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 3/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.9772 - accuracy: 0.5828 - val_loss: 0.8826 - val_accuracy: 0.6931
#
# Epoch 00003: val_accuracy improved from 0.68638 to 0.69308, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 4/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.9768 - accuracy: 0.5781 - val_loss: 0.8511 - val_accuracy: 0.7121
#
# Epoch 00004: val_accuracy improved from 0.69308 to 0.71205, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 5/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.9173 - accuracy: 0.6415 - val_loss: 0.8351 - val_accuracy: 0.7193
#
# Epoch 00005: val_accuracy improved from 0.71205 to 0.71931, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 6/45
# 101/101 [==============================] - 16s 157ms/step - loss: 0.8966 - accuracy: 0.6390 - val_loss: 0.8048 - val_accuracy: 0.7232
#
# Epoch 00006: val_accuracy improved from 0.71931 to 0.72321, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 7/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.8693 - accuracy: 0.6675 - val_loss: 0.7747 - val_accuracy: 0.7338
#
# Epoch 00007: val_accuracy improved from 0.72321 to 0.73382, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 8/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.8379 - accuracy: 0.6802 - val_loss: 0.7691 - val_accuracy: 0.7355
#
# Epoch 00008: val_accuracy improved from 0.73382 to 0.73549, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 9/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.8201 - accuracy: 0.6945 - val_loss: 0.7333 - val_accuracy: 0.7394
#
# Epoch 00009: val_accuracy improved from 0.73549 to 0.73940, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 10/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.7917 - accuracy: 0.7046 - val_loss: 0.7269 - val_accuracy: 0.7455
#
# Epoch 00010: val_accuracy improved from 0.73940 to 0.74554, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 11/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.7732 - accuracy: 0.7287 - val_loss: 0.7115 - val_accuracy: 0.7422
#
# Epoch 00011: val_accuracy did not improve from 0.74554
# Epoch 12/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.7512 - accuracy: 0.7228 - val_loss: 0.6768 - val_accuracy: 0.7550
#
# Epoch 00012: val_accuracy improved from 0.74554 to 0.75502, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 13/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.7464 - accuracy: 0.7422 - val_loss: 0.6645 - val_accuracy: 0.7589
#
# Epoch 00013: val_accuracy improved from 0.75502 to 0.75893, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 14/45
# 101/101 [==============================] - 16s 161ms/step - loss: 0.7228 - accuracy: 0.7376 - val_loss: 0.6542 - val_accuracy: 0.7584
#
# Epoch 00014: val_accuracy did not improve from 0.75893
# Epoch 15/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.7095 - accuracy: 0.7664 - val_loss: 0.6648 - val_accuracy: 0.7517
#
# Epoch 00015: val_accuracy did not improve from 0.75893
# Epoch 16/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6835 - accuracy: 0.7654 - val_loss: 0.6658 - val_accuracy: 0.7422
#
# Epoch 00016: val_accuracy did not improve from 0.75893
# Epoch 17/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6788 - accuracy: 0.7647 - val_loss: 0.6602 - val_accuracy: 0.7528
#
# Epoch 00017: val_accuracy did not improve from 0.75893
# Epoch 18/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6616 - accuracy: 0.7791 - val_loss: 0.6406 - val_accuracy: 0.7467
#
# Epoch 00018: val_accuracy did not improve from 0.75893
# Epoch 19/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6481 - accuracy: 0.7878 - val_loss: 0.6205 - val_accuracy: 0.7545
#
# Epoch 00019: val_accuracy did not improve from 0.75893
# Epoch 20/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6497 - accuracy: 0.7982 - val_loss: 0.6256 - val_accuracy: 0.7600
#
# Epoch 00020: val_accuracy improved from 0.75893 to 0.76004, saving model to /local/data1/elech646/code/train_logs/vgg19_t1ce_flair_sagittal_transfer.h5
# Epoch 21/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6410 - accuracy: 0.7848 - val_loss: 0.6348 - val_accuracy: 0.7533
#
# Epoch 00021: val_accuracy did not improve from 0.76004
# Epoch 22/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.6388 - accuracy: 0.7909 - val_loss: 0.6255 - val_accuracy: 0.7539
#
# Epoch 00022: val_accuracy did not improve from 0.76004
# Epoch 23/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6428 - accuracy: 0.7936 - val_loss: 0.6236 - val_accuracy: 0.7561
#
# Epoch 00023: val_accuracy did not improve from 0.76004
# Epoch 24/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6449 - accuracy: 0.7938 - val_loss: 0.6266 - val_accuracy: 0.7528
#
# Epoch 00024: val_accuracy did not improve from 0.76004
# Epoch 25/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6327 - accuracy: 0.7990 - val_loss: 0.6219 - val_accuracy: 0.7533
#
# Epoch 00025: val_accuracy did not improve from 0.76004
# Epoch 26/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6413 - accuracy: 0.8015 - val_loss: 0.6283 - val_accuracy: 0.7522
#
# Epoch 00026: val_accuracy did not improve from 0.76004
# Epoch 27/45
# 101/101 [==============================] - 17s 172ms/step - loss: 0.6260 - accuracy: 0.8057 - val_loss: 0.6274 - val_accuracy: 0.7573
#
# Epoch 00027: val_accuracy did not improve from 0.76004
# Epoch 28/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6263 - accuracy: 0.7910 - val_loss: 0.6233 - val_accuracy: 0.7533
#
# Epoch 00028: val_accuracy did not improve from 0.76004
# Epoch 29/45
# 101/101 [==============================] - 16s 158ms/step - loss: 0.6366 - accuracy: 0.7949 - val_loss: 0.6198 - val_accuracy: 0.7522
#
# Epoch 00029: val_accuracy did not improve from 0.76004
# Epoch 30/45
# 101/101 [==============================] - 16s 157ms/step - loss: 0.6305 - accuracy: 0.8019 - val_loss: 0.6157 - val_accuracy: 0.7522
#
# Epoch 00030: val_accuracy did not improve from 0.76004
# Epoch 31/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6312 - accuracy: 0.7943 - val_loss: 0.6235 - val_accuracy: 0.7506
#
# Epoch 00031: val_accuracy did not improve from 0.76004
# Epoch 32/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6508 - accuracy: 0.7920 - val_loss: 0.6184 - val_accuracy: 0.7522
#
# Epoch 00032: val_accuracy did not improve from 0.76004
# Epoch 33/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6207 - accuracy: 0.8027 - val_loss: 0.6178 - val_accuracy: 0.7550
#
# Epoch 00033: val_accuracy did not improve from 0.76004
# Epoch 34/45
# 101/101 [==============================] - 16s 160ms/step - loss: 0.6340 - accuracy: 0.8014 - val_loss: 0.6188 - val_accuracy: 0.7533
#
# Epoch 00034: val_accuracy did not improve from 0.76004
# Epoch 35/45
# 101/101 [==============================] - 16s 159ms/step - loss: 0.6120 - accuracy: 0.8020 - val_loss: 0.6194 - val_accuracy: 0.7506
# Restoring model weights from the end of the best epoch.
#
# Epoch 00035: val_accuracy did not improve from 0.76004
# Epoch 00035: early stopping
# Training took: 578.18 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(50, activation = 'relu')(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 504.78 s $\approx 8$ min
#
# test accuracy: 0.7545 (overfit)
#
# ------------------------------------------------------------------------------------------------------------------
#
# 2nd training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(50, activation = 'relu')(x)
#         x = Dropout(0.2)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 503.75 s $\approx 8$ min
#
# test accuracy: 0.7210 (less overfit, room for more learning)
#
# ------------------------------------------------------------------------------------------------------------------
#
# 3rd training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(50, activation = 'relu')(x)
#         x = Dropout(0.35)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 45
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 578.18 s $\approx 9$ min
#
# test accuracy: 0.7455

# %%
print(len(train.labels) // batch_size)

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.6091
# Test accuracy: 0.7455

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

# Plot accuracy
plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('3rd training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.savefig('VGG19_3rd_training_t1ce_flair_sagittal_acc.png', dpi = 300)
plt.show()

# Plot loss
plt.plot(n_epochs, loss, label = 'Training loss')
plt.plot(n_epochs, val_loss, label = 'Validation loss')
plt.title('3rd training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'best')
plt.savefig('VGG19_3rd_training_t1ce_flair_sagittal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'PuBu') # viridis, YlGnBu
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
plt.savefig('3rd_Training_CM_t1ce_flair_sagittal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
clsf_report.to_csv('Classification Report-3rd Training on t1ce_flair sagittal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.23      0.17        60
#            1       0.70      0.61      0.65       130
#            2       0.91      0.82      0.86       312
#
#     accuracy                           0.70       502
#    macro avg       0.58      0.55      0.56       502
# weighted avg       0.76      0.70      0.72       502

# %%
# for fancy LaTeX style plots
from matplotlib import rc
import matplotlib.pylab as plt

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex = True)

x = plt.linspace(0, 20)
plt.plot(x, plt.sin(x))
plt.xlabel(r"$x$", size = 20)
plt.ylabel(r"$\sin(x)$", size = 20)
plt.show()
