# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
physical_devices # VICTORY

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(horizontal_flip = False, 
                                   vertical_flip = False,
                                   brightness_range = [0.5, 1.25],
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(horizontal_flip = False, 
                                  vertical_flip = False,
                                  rotation_range = 0,
                                  samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 8887 images belonging to 3 classes.
# Found 2584 images belonging to 3 classes.
# Found 647 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.35956404

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(30, activation = 'relu')(x)
x = Dropout(0.4)(x)
x = Dense(20, activation = 'relu')(x)
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 30)                752670
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 20,777,737
# Trainable params: 753,353
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_sagittal_t1_flair_3rd.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer_history.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience = 15, 
                   verbose = 1, restore_best_weights = True)

# %%
# Compile model
model.compile(Adam(lr = 1e-5),   
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 45 
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])
# maybe add argument use_multiprocessing = True

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/45
# 138/138 [==============================] - 23s 161ms/step - loss: 1.1714 - accuracy: 0.3400 - val_loss: 1.0883 - val_accuracy: 0.3840
#
# Epoch 00001: val_accuracy improved from -inf to 0.38398, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 2/45
# 138/138 [==============================] - 22s 160ms/step - loss: 1.0536 - accuracy: 0.4095 - val_loss: 1.0351 - val_accuracy: 0.5781
#
# Epoch 00002: val_accuracy improved from 0.38398 to 0.57812, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 3/45
# 138/138 [==============================] - 22s 160ms/step - loss: 1.0096 - accuracy: 0.4738 - val_loss: 1.0252 - val_accuracy: 0.5867
#
# Epoch 00003: val_accuracy improved from 0.57812 to 0.58672, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 4/45
# 138/138 [==============================] - 22s 159ms/step - loss: 0.9875 - accuracy: 0.4941 - val_loss: 1.0237 - val_accuracy: 0.5895
#
# Epoch 00004: val_accuracy improved from 0.58672 to 0.58945, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 5/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.9762 - accuracy: 0.5036 - val_loss: 0.9963 - val_accuracy: 0.6234
#
# Epoch 00005: val_accuracy improved from 0.58945 to 0.62344, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 6/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.9529 - accuracy: 0.5257 - val_loss: 0.9640 - val_accuracy: 0.6570
#
# Epoch 00006: val_accuracy improved from 0.62344 to 0.65703, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 7/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.9402 - accuracy: 0.5574 - val_loss: 0.9632 - val_accuracy: 0.6465
#
# Epoch 00007: val_accuracy did not improve from 0.65703
# Epoch 8/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.9186 - accuracy: 0.5619 - val_loss: 0.9630 - val_accuracy: 0.6281
#
# Epoch 00008: val_accuracy did not improve from 0.65703
# Epoch 9/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.9071 - accuracy: 0.5633 - val_loss: 0.9092 - val_accuracy: 0.6656
#
# Epoch 00009: val_accuracy improved from 0.65703 to 0.66562, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 10/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8919 - accuracy: 0.5800 - val_loss: 0.9217 - val_accuracy: 0.6570
#
# Epoch 00010: val_accuracy did not improve from 0.66562
# Epoch 11/45
# 138/138 [==============================] - 22s 159ms/step - loss: 0.8835 - accuracy: 0.5814 - val_loss: 0.9115 - val_accuracy: 0.6645
#
# Epoch 00011: val_accuracy did not improve from 0.66562
# Epoch 12/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8669 - accuracy: 0.6046 - val_loss: 0.8978 - val_accuracy: 0.6633
#
# Epoch 00012: val_accuracy did not improve from 0.66562
# Epoch 13/45
# 138/138 [==============================] - 22s 162ms/step - loss: 0.8545 - accuracy: 0.6081 - val_loss: 0.8993 - val_accuracy: 0.6609
#
# Epoch 00013: val_accuracy did not improve from 0.66562
# Epoch 14/45
# 138/138 [==============================] - 22s 162ms/step - loss: 0.8423 - accuracy: 0.6174 - val_loss: 0.8864 - val_accuracy: 0.6637
#
# Epoch 00014: val_accuracy did not improve from 0.66562
# Epoch 15/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8214 - accuracy: 0.6259 - val_loss: 0.8750 - val_accuracy: 0.6676
#
# Epoch 00015: val_accuracy improved from 0.66562 to 0.66758, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 16/45
# 138/138 [==============================] - 23s 165ms/step - loss: 0.8232 - accuracy: 0.6272 - val_loss: 0.8841 - val_accuracy: 0.6664
#
# Epoch 00016: val_accuracy did not improve from 0.66758
# Epoch 17/45
# 138/138 [==============================] - 23s 166ms/step - loss: 0.8204 - accuracy: 0.6331 - val_loss: 0.8719 - val_accuracy: 0.6703
#
# Epoch 00017: val_accuracy improved from 0.66758 to 0.67031, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 18/45
# 138/138 [==============================] - 23s 167ms/step - loss: 0.8139 - accuracy: 0.6364 - val_loss: 0.8783 - val_accuracy: 0.6645
#
# Epoch 00018: val_accuracy did not improve from 0.67031
# Epoch 19/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8153 - accuracy: 0.6408 - val_loss: 0.8740 - val_accuracy: 0.6687
#
# Epoch 00019: val_accuracy did not improve from 0.67031
# Epoch 20/45
# 138/138 [==============================] - 22s 159ms/step - loss: 0.8257 - accuracy: 0.6395 - val_loss: 0.8718 - val_accuracy: 0.6734
#
# Epoch 00020: val_accuracy improved from 0.67031 to 0.67344, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 21/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8139 - accuracy: 0.6490 - val_loss: 0.8737 - val_accuracy: 0.6707
#
# Epoch 00021: val_accuracy did not improve from 0.67344
# Epoch 22/45
# 138/138 [==============================] - 22s 162ms/step - loss: 0.8232 - accuracy: 0.6273 - val_loss: 0.8726 - val_accuracy: 0.6711
#
# Epoch 00022: val_accuracy did not improve from 0.67344
# Epoch 23/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8085 - accuracy: 0.6425 - val_loss: 0.8718 - val_accuracy: 0.6691
#
# Epoch 00023: val_accuracy did not improve from 0.67344
# Epoch 24/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.7998 - accuracy: 0.6582 - val_loss: 0.8704 - val_accuracy: 0.6699
#
# Epoch 00024: val_accuracy did not improve from 0.67344
# Epoch 25/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8150 - accuracy: 0.6430 - val_loss: 0.8674 - val_accuracy: 0.6707
#
# Epoch 00025: val_accuracy did not improve from 0.67344
# Epoch 26/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8044 - accuracy: 0.6373 - val_loss: 0.8677 - val_accuracy: 0.6719
#
# Epoch 00026: val_accuracy did not improve from 0.67344
# Epoch 27/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8110 - accuracy: 0.6374 - val_loss: 0.8655 - val_accuracy: 0.6730
#
# Epoch 00027: val_accuracy did not improve from 0.67344
# Epoch 28/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8011 - accuracy: 0.6497 - val_loss: 0.8635 - val_accuracy: 0.6727
#
# Epoch 00028: val_accuracy did not improve from 0.67344
# Epoch 29/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8068 - accuracy: 0.6329 - val_loss: 0.8690 - val_accuracy: 0.6695
#
# Epoch 00029: val_accuracy did not improve from 0.67344
# Epoch 30/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8019 - accuracy: 0.6527 - val_loss: 0.8673 - val_accuracy: 0.6711
#
# Epoch 00030: val_accuracy did not improve from 0.67344
# Epoch 31/45
# 138/138 [==============================] - 22s 159ms/step - loss: 0.8032 - accuracy: 0.6487 - val_loss: 0.8644 - val_accuracy: 0.6734
#
# Epoch 00031: val_accuracy did not improve from 0.67344
# Epoch 32/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7993 - accuracy: 0.6526 - val_loss: 0.8658 - val_accuracy: 0.6707
#
# Epoch 00032: val_accuracy did not improve from 0.67344
# Epoch 33/45
# 138/138 [==============================] - 22s 159ms/step - loss: 0.8065 - accuracy: 0.6499 - val_loss: 0.8598 - val_accuracy: 0.6730
#
# Epoch 00033: val_accuracy did not improve from 0.67344
# Epoch 34/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8125 - accuracy: 0.6390 - val_loss: 0.8602 - val_accuracy: 0.6750
#
# Epoch 00034: val_accuracy improved from 0.67344 to 0.67500, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 35/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8032 - accuracy: 0.6416 - val_loss: 0.8650 - val_accuracy: 0.6691
#
# Epoch 00035: val_accuracy did not improve from 0.67500
# Epoch 36/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.7944 - accuracy: 0.6521 - val_loss: 0.8588 - val_accuracy: 0.6770
#
# Epoch 00036: val_accuracy improved from 0.67500 to 0.67695, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 37/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7931 - accuracy: 0.6553 - val_loss: 0.8610 - val_accuracy: 0.6734
#
# Epoch 00037: val_accuracy did not improve from 0.67695
# Epoch 38/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7955 - accuracy: 0.6471 - val_loss: 0.8616 - val_accuracy: 0.6734
#
# Epoch 00038: val_accuracy did not improve from 0.67695
# Epoch 39/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8053 - accuracy: 0.6504 - val_loss: 0.8538 - val_accuracy: 0.6777
#
# Epoch 00039: val_accuracy improved from 0.67695 to 0.67773, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 40/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8026 - accuracy: 0.6485 - val_loss: 0.8591 - val_accuracy: 0.6715
#
# Epoch 00040: val_accuracy did not improve from 0.67773
# Epoch 41/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8043 - accuracy: 0.6392 - val_loss: 0.8549 - val_accuracy: 0.6766
#
# Epoch 00041: val_accuracy did not improve from 0.67773
# Epoch 42/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8018 - accuracy: 0.6407 - val_loss: 0.8533 - val_accuracy: 0.6770
#
# Epoch 00042: val_accuracy did not improve from 0.67773
# Epoch 43/45
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7881 - accuracy: 0.6487 - val_loss: 0.8502 - val_accuracy: 0.6801
#
# Epoch 00043: val_accuracy improved from 0.67773 to 0.68008, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 44/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.7857 - accuracy: 0.6638 - val_loss: 0.8535 - val_accuracy: 0.6766
#
# Epoch 00044: val_accuracy did not improve from 0.68008
# Epoch 45/45
# 138/138 [==============================] - 22s 161ms/step - loss: 0.7973 - accuracy: 0.6534 - val_loss: 0.8540 - val_accuracy: 0.6738
#
# Epoch 00045: val_accuracy did not improve from 0.68008
# Training took: 1014.34 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(50, activation = 'relu')(x)
#         x = Dropout(0.35)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 45
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 539.04 s $\approx 8$ min
#
# test accuracy: 0.6750 (slight overfit)
#
# ------------------------------------------------------------------------------------------------------------------
#
# 2nd training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(30, activation = 'relu')(x)
#         x = Dropout(0.35)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 45
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 608.35 s $\approx 10$ min
#
# test accuracy: 0.7109 (slightly overfit)
#
# ------------------------------------------------------------------------------------------------------------------
#
# 3rd training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(30, activation = 'relu')(x)
#         x = Dropout(0.4)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 45
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 1014.34 s $\approx 17$ min
#
# test accuracy: 0.7234 (underfit)

# %%
print(len(train.labels) // batch_size)

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.7697
# Test accuracy: 0.7234

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

# Plot accuracy
plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('3rd training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.savefig('VGG19_3rd_training_t1ce_flair_sagittal_acc.png', dpi = 300)
plt.show()

# Plot loss
plt.plot(n_epochs, loss, label = 'Training loss')
plt.plot(n_epochs, val_loss, label = 'Validation loss')
plt.title('3rd training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'best')
plt.savefig('VGG19_3rd_training_t1ce_flair_sagittal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'PuBu') # viridis, YlGnBu
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
plt.savefig('3rd_Training_CM_t1ce_flair_sagittal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
clsf_report.to_csv('Classification Report-3rd Training on t1_flair sagittal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.40      0.49       157
#            1       0.64      0.83      0.73       216
#            2       0.84      0.82      0.83       274
#
#     accuracy                           0.72       647
#    macro avg       0.70      0.68      0.68       647
# weighted avg       0.72      0.72      0.71       647

# %%
# for fancy LaTeX style plots
from matplotlib import rc
import matplotlib.pylab as plt

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex = True)

x = plt.linspace(0, 20)
plt.plot(x, plt.sin(x))
plt.xlabel(r"$x$", size = 20)
plt.ylabel(r"$\sin(x)$", size = 20)
plt.show()
