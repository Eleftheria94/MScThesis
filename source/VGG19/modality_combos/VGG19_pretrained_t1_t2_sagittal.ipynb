# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
# import tensorflow_addons as tfa
# from tensorflow_addons.optimizers import Lookahead
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
physical_devices # VICTORY
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(horizontal_flip = False, 
                                   vertical_flip = False,
                                   brightness_range = [0.5, 1.25],
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(horizontal_flip = False, 
                                  vertical_flip = False,
                                  rotation_range = 0,
                                  samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_t2_sagittal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_t2_sagittal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_t2_sagittal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 8917 images belonging to 3 classes.
# Found 2239 images belonging to 3 classes.
# Found 873 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.33876348

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(32, activation = 'relu')(x)
x = Dropout(0.5)(x)
x = Dense(32, activation = 'relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                802848
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 20,828,387
# Trainable params: 804,003
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_sagittal_t1_t2_sagittal.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer_history.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience = 15, restore_best_weights = True)

# %%
# Compile model
model.compile(Adam(lr = 1e-5),   
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 30 
batch_size = 64
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])
# maybe add argument use_multiprocessing = True

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/30
# 139/139 [==============================] - 22s 157ms/step - loss: 1.0968 - accuracy: 0.3830 - val_loss: 0.9312 - val_accuracy: 0.5850
#
# Epoch 00001: val_accuracy improved from -inf to 0.58502, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 2/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.9639 - accuracy: 0.5363 - val_loss: 0.8731 - val_accuracy: 0.6278
#
# Epoch 00002: val_accuracy improved from 0.58502 to 0.62776, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 3/30
# 139/139 [==============================] - 22s 155ms/step - loss: 0.9025 - accuracy: 0.5910 - val_loss: 0.8459 - val_accuracy: 0.6310
#
# Epoch 00003: val_accuracy improved from 0.62776 to 0.63097, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 4/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.8751 - accuracy: 0.6125 - val_loss: 0.8262 - val_accuracy: 0.6209
#
# Epoch 00004: val_accuracy did not improve from 0.63097
# Epoch 5/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.8434 - accuracy: 0.6314 - val_loss: 0.7879 - val_accuracy: 0.6498
#
# Epoch 00005: val_accuracy improved from 0.63097 to 0.64982, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 6/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.8121 - accuracy: 0.6544 - val_loss: 0.7614 - val_accuracy: 0.6503
#
# Epoch 00006: val_accuracy improved from 0.64982 to 0.65028, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 7/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.7861 - accuracy: 0.6739 - val_loss: 0.7501 - val_accuracy: 0.6567
#
# Epoch 00007: val_accuracy improved from 0.65028 to 0.65671, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 8/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.7658 - accuracy: 0.6886 - val_loss: 0.7410 - val_accuracy: 0.6558
#
# Epoch 00008: val_accuracy did not improve from 0.65671
# Epoch 9/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.7199 - accuracy: 0.7169 - val_loss: 0.7466 - val_accuracy: 0.6475
#
# Epoch 00009: val_accuracy did not improve from 0.65671
# Epoch 10/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.6998 - accuracy: 0.7249 - val_loss: 0.7186 - val_accuracy: 0.6742
#
# Epoch 00010: val_accuracy improved from 0.65671 to 0.67417, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 11/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.6866 - accuracy: 0.7388 - val_loss: 0.7182 - val_accuracy: 0.6705
#
# Epoch 00011: val_accuracy did not improve from 0.67417
# Epoch 12/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.6676 - accuracy: 0.7440 - val_loss: 0.7041 - val_accuracy: 0.6728
#
# Epoch 00012: val_accuracy did not improve from 0.67417
# Epoch 13/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.6466 - accuracy: 0.7566 - val_loss: 0.7002 - val_accuracy: 0.6783
#
# Epoch 00013: val_accuracy improved from 0.67417 to 0.67831, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 14/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.6262 - accuracy: 0.7690 - val_loss: 0.6972 - val_accuracy: 0.6815
#
# Epoch 00014: val_accuracy improved from 0.67831 to 0.68153, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 15/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.6096 - accuracy: 0.7722 - val_loss: 0.6827 - val_accuracy: 0.6857
#
# Epoch 00015: val_accuracy improved from 0.68153 to 0.68566, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 16/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.5950 - accuracy: 0.7844 - val_loss: 0.6870 - val_accuracy: 0.6700
#
# Epoch 00016: val_accuracy did not improve from 0.68566
# Epoch 17/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.5790 - accuracy: 0.7932 - val_loss: 0.6985 - val_accuracy: 0.6636
#
# Epoch 00017: val_accuracy did not improve from 0.68566
# Epoch 18/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.5676 - accuracy: 0.7968 - val_loss: 0.6736 - val_accuracy: 0.6806
#
# Epoch 00018: val_accuracy did not improve from 0.68566
# Epoch 19/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.5564 - accuracy: 0.7999 - val_loss: 0.6863 - val_accuracy: 0.6811
#
# Epoch 00019: val_accuracy did not improve from 0.68566
# Epoch 20/30
# 139/139 [==============================] - 22s 158ms/step - loss: 0.5371 - accuracy: 0.8106 - val_loss: 0.6750 - val_accuracy: 0.6797
#
# Epoch 00020: val_accuracy did not improve from 0.68566
# Epoch 21/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.5237 - accuracy: 0.8162 - val_loss: 0.6676 - val_accuracy: 0.6811
#
# Epoch 00021: val_accuracy did not improve from 0.68566
# Epoch 22/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.5307 - accuracy: 0.8181 - val_loss: 0.6681 - val_accuracy: 0.6792
#
# Epoch 00022: val_accuracy did not improve from 0.68566
# Epoch 23/30
# 139/139 [==============================] - 22s 158ms/step - loss: 0.5202 - accuracy: 0.8173 - val_loss: 0.6764 - val_accuracy: 0.6783
#
# Epoch 00023: val_accuracy did not improve from 0.68566
# Epoch 24/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.5190 - accuracy: 0.8174 - val_loss: 0.6680 - val_accuracy: 0.6806
#
# Epoch 00024: val_accuracy did not improve from 0.68566
# Epoch 25/30
# 139/139 [==============================] - 22s 157ms/step - loss: 0.5107 - accuracy: 0.8266 - val_loss: 0.6670 - val_accuracy: 0.6829
#
# Epoch 00025: val_accuracy did not improve from 0.68566
# Epoch 26/30
# 139/139 [==============================] - 22s 155ms/step - loss: 0.5217 - accuracy: 0.8200 - val_loss: 0.6678 - val_accuracy: 0.6861
#
# Epoch 00026: val_accuracy improved from 0.68566 to 0.68612, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_t2_sagittal_transfer.h5
# Epoch 27/30
# 139/139 [==============================] - 22s 154ms/step - loss: 0.4990 - accuracy: 0.8333 - val_loss: 0.6707 - val_accuracy: 0.6811
#
# Epoch 00027: val_accuracy did not improve from 0.68612
# Epoch 28/30
# 139/139 [==============================] - 22s 155ms/step - loss: 0.5120 - accuracy: 0.8284 - val_loss: 0.6686 - val_accuracy: 0.6820
#
# Epoch 00028: val_accuracy did not improve from 0.68612
# Epoch 29/30
# 139/139 [==============================] - 22s 155ms/step - loss: 0.5110 - accuracy: 0.8204 - val_loss: 0.6692 - val_accuracy: 0.6820
#
# Epoch 00029: val_accuracy did not improve from 0.68612
# Epoch 30/30
# 139/139 [==============================] - 22s 156ms/step - loss: 0.5137 - accuracy: 0.8253 - val_loss: 0.6692 - val_accuracy: 0.6774
#
# Epoch 00030: val_accuracy did not improve from 0.68612
# Training took: 662.56 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#          x = Flatten()(x)
#          x = Dense(50, activation = 'relu')(x)
#          x = Dense(20, activation = 'relu')(x)
#          predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 128
#
# number of epochs = 40
#
# learning rate = 1e-5 with `ReduceLROnPlateau`
#
# training time: 1382.22 s $\approx 23$ min
#
# test accuracy: 0.6313 overfit
#
# ------------------------------------------------------------------------------------------------------------------
# 2nd training
#
# Setup : `x = vgg_19.output
#          x = Flatten()(x)
#          x = Dense(50, activation = 'relu')(x)
#          x = Dropout(0.2)(x)
#          x = Dense(20, activation = 'relu')(x)
#          x = Dropout(0.2)(x)
#          predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 1382.22 s $\approx 23$ min
#
# test accuracy: 71.56% (overfitting but there was continuous learning)

# %%
print(len(train.labels) // batch_size)

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.8974
# Test accuracy: 0.6562

# %%
# Plot training + validation accuracy per epoch
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('2nd training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
#plt.savefig('VGG19_1st_training_t1_flair_sagittal_acc.png', dpi = 300)
plt.show()

plt.plot(n_epochs, loss, label = 'Training accuracy')
plt.plot(n_epochs, val_loss, label = 'Validation accuracy')
plt.title('2nd training')
plt.xlabel('Epochs')
plt.ylabel('Cross-entropy')
plt.legend(loc = 'best')
#plt.savefig('VGG19_1st_training_t1_flair_sagittal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'Blues')
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
#plt.savefig('2nd_Training_CM_t1_flair_sagittal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
# clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
# clsf_report.to_csv('Classification Report-3rd Training on t1_flair sagittal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.32      0.41       157
#            1       0.63      0.81      0.71       216
#            2       0.84      0.86      0.85       274
#
#     accuracy                           0.71       647
#    macro avg       0.68      0.66      0.66       647
# weighted avg       0.70      0.71      0.70       647
