# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(#horizontal_flip = True, 
                                   #vertical_flip = True,
                                   #rotation_range = 45,
                                   brightness_range = [0.5, 1.5],
                                   #fill_mode = 'constant',
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(horizontal_flip = False, 
                                  vertical_flip = False,
                                  rotation_range = 0,
                                  samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t2_sagittal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t2_sagittal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t2_sagittal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 4509 images belonging to 3 classes.
# Found 1164 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.42873877

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(30, activation = 'relu')(x) 
x = Dropout(0.5)(x)
x = Dense(20, activation = 'relu')(x) 
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 30)                752670
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 20,777,737
# Trainable params: 753,353
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_t2_sagittal.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_transfer_history_t2_sagittal.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', verbose = 1, 
                   patience = 15)

# %%
# Compile model
model.compile(Adam(lr = 1e-5),  
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 30 
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/30
# 70/70 [==============================] - 12s 163ms/step - loss: 1.1850 - accuracy: 0.3569 - val_loss: 1.0586 - val_accuracy: 0.5087
#
# Epoch 00001: val_accuracy improved from -inf to 0.50868, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 2/30
# 70/70 [==============================] - 11s 160ms/step - loss: 1.0670 - accuracy: 0.4309 - val_loss: 1.0146 - val_accuracy: 0.5547
#
# Epoch 00002: val_accuracy improved from 0.50868 to 0.55469, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 3/30
# 70/70 [==============================] - 11s 160ms/step - loss: 1.0089 - accuracy: 0.5108 - val_loss: 0.9752 - val_accuracy: 0.5911
#
# Epoch 00003: val_accuracy improved from 0.55469 to 0.59115, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 4/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.9934 - accuracy: 0.5305 - val_loss: 0.9523 - val_accuracy: 0.6406
#
# Epoch 00004: val_accuracy improved from 0.59115 to 0.64062, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 5/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.9745 - accuracy: 0.5344 - val_loss: 0.9201 - val_accuracy: 0.6441
#
# Epoch 00005: val_accuracy improved from 0.64062 to 0.64410, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 6/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.9646 - accuracy: 0.5457 - val_loss: 0.9086 - val_accuracy: 0.6406
#
# Epoch 00006: val_accuracy did not improve from 0.64410
# Epoch 7/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.9435 - accuracy: 0.5660 - val_loss: 0.8916 - val_accuracy: 0.6502
#
# Epoch 00007: val_accuracy improved from 0.64410 to 0.65017, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 8/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.9214 - accuracy: 0.5838 - val_loss: 0.8848 - val_accuracy: 0.6519
#
# Epoch 00008: val_accuracy improved from 0.65017 to 0.65191, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 9/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.9203 - accuracy: 0.5763 - val_loss: 0.8710 - val_accuracy: 0.6450
#
# Epoch 00009: val_accuracy did not improve from 0.65191
# Epoch 10/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8932 - accuracy: 0.6027 - val_loss: 0.8558 - val_accuracy: 0.6580
#
# Epoch 00010: val_accuracy improved from 0.65191 to 0.65799, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 11/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8882 - accuracy: 0.5968 - val_loss: 0.8473 - val_accuracy: 0.6562
#
# Epoch 00011: val_accuracy did not improve from 0.65799
# Epoch 12/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8762 - accuracy: 0.6039 - val_loss: 0.8584 - val_accuracy: 0.6458
#
# Epoch 00012: val_accuracy did not improve from 0.65799
# Epoch 13/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.8846 - accuracy: 0.6031 - val_loss: 0.8415 - val_accuracy: 0.6562
#
# Epoch 00013: val_accuracy did not improve from 0.65799
# Epoch 14/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8465 - accuracy: 0.6254 - val_loss: 0.8344 - val_accuracy: 0.6745
#
# Epoch 00014: val_accuracy improved from 0.65799 to 0.67448, saving model to /local/data1/elech646/code/train_logs/vgg19_transfer_t2_sagittal.h5
# Epoch 15/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8516 - accuracy: 0.6285 - val_loss: 0.8232 - val_accuracy: 0.6710
#
# Epoch 00015: val_accuracy did not improve from 0.67448
# Epoch 16/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.8320 - accuracy: 0.6244 - val_loss: 0.8230 - val_accuracy: 0.6589
#
# Epoch 00016: val_accuracy did not improve from 0.67448
# Epoch 17/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8231 - accuracy: 0.6464 - val_loss: 0.8076 - val_accuracy: 0.6632
#
# Epoch 00017: val_accuracy did not improve from 0.67448
# Epoch 18/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8061 - accuracy: 0.6637 - val_loss: 0.8071 - val_accuracy: 0.6693
#
# Epoch 00018: val_accuracy did not improve from 0.67448
# Epoch 19/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.8013 - accuracy: 0.6566 - val_loss: 0.8075 - val_accuracy: 0.6476
#
# Epoch 00019: val_accuracy did not improve from 0.67448
# Epoch 20/30
# 70/70 [==============================] - 11s 162ms/step - loss: 0.7868 - accuracy: 0.6756 - val_loss: 0.8006 - val_accuracy: 0.6641
#
# Epoch 00020: val_accuracy did not improve from 0.67448
# Epoch 21/30
# 70/70 [==============================] - 12s 166ms/step - loss: 0.7898 - accuracy: 0.6707 - val_loss: 0.7983 - val_accuracy: 0.6667
#
# Epoch 00021: val_accuracy did not improve from 0.67448
# Epoch 22/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.8065 - accuracy: 0.6617 - val_loss: 0.7980 - val_accuracy: 0.6641
#
# Epoch 00022: val_accuracy did not improve from 0.67448
# Epoch 23/30
# 70/70 [==============================] - 12s 167ms/step - loss: 0.7979 - accuracy: 0.6478 - val_loss: 0.8013 - val_accuracy: 0.6571
#
# Epoch 00023: val_accuracy did not improve from 0.67448
# Epoch 24/30
# 70/70 [==============================] - 12s 168ms/step - loss: 0.7767 - accuracy: 0.6893 - val_loss: 0.8000 - val_accuracy: 0.6597
#
# Epoch 00024: val_accuracy did not improve from 0.67448
# Epoch 25/30
# 70/70 [==============================] - 11s 163ms/step - loss: 0.7871 - accuracy: 0.6828 - val_loss: 0.7973 - val_accuracy: 0.6641
#
# Epoch 00025: val_accuracy did not improve from 0.67448
# Epoch 26/30
# 70/70 [==============================] - 12s 169ms/step - loss: 0.7841 - accuracy: 0.6616 - val_loss: 0.7954 - val_accuracy: 0.6623
#
# Epoch 00026: val_accuracy did not improve from 0.67448
# Epoch 27/30
# 70/70 [==============================] - 12s 164ms/step - loss: 0.7792 - accuracy: 0.6844 - val_loss: 0.7955 - val_accuracy: 0.6727
#
# Epoch 00027: val_accuracy did not improve from 0.67448
# Epoch 28/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.7837 - accuracy: 0.6628 - val_loss: 0.7954 - val_accuracy: 0.6606
#
# Epoch 00028: val_accuracy did not improve from 0.67448
# Epoch 29/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.7960 - accuracy: 0.6667 - val_loss: 0.7978 - val_accuracy: 0.6615
#
# Epoch 00029: val_accuracy did not improve from 0.67448
# Epoch 00029: early stopping
# Training took: 336.65 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(30, activation = 'relu')(x)
#         x = Dropout(0.5)(x)
#         x = Dense(20, activation = 'relu')(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 227.93 s $\approx 4$ min
#
# test accuracy: 0.6667

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.8366
# Test accuracy: 0.6328

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

# for fancy LaTeX style plots
from matplotlib import rc
import matplotlib.pylab as plt

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex = True)

# Plot accuracy
plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('1st training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.savefig('VGG19_1st_training_t2_sagittal_acc.png', dpi = 300)
plt.show()

# Plot loss
plt.plot(n_epochs, loss, label = 'Training loss')
plt.plot(n_epochs, val_loss, label = 'Validation loss')
plt.title('1st training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'best')
plt.savefig('VGG19_1st_training_t2_sagittal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'PuBu')
for t in ax.texts: 
    t.set_text(t.get_text().replace('%', '\%'))
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
plt.savefig('VGG19_1st_training_CM_t2_sagittal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
clsf_report.to_csv('Classification Report-1st Training on t2 sagittal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.39      0.43        33
#            1       0.41      0.33      0.37       137
#            2       0.70      0.80      0.75       235
#
#     accuracy                           0.61       405
#    macro avg       0.53      0.51      0.52       405
# weighted avg       0.59      0.61      0.59       405
