# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')

tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2022-04-18 16:25:02.537576: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-18 16:25:04.061097: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-18 16:25:04.061721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-18 16:25:04.077247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 16:25:04.077401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2022-04-18 16:25:04.077417: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-18 16:25:04.078572: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-18 16:25:04.078595: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-18 16:25:04.079764: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-18 16:25:04.079920: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-18 16:25:04.081082: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-18 16:25:04.081684: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-18 16:25:04.084094: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-18 16:25:04.084184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 16:25:04.084363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 16:25:04.084468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(#horizontal_flip = True, 
                                   #vertical_flip = True,
                                   #rotation_range = 45,
                                   brightness_range = [0.5, 2], 
                                   #fill_mode = 'constant', 
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_flair_frontal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_flair_frontal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_flair_frontal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 6067 images belonging to 3 classes.
# Found 1677 images belonging to 3 classes.
# Found 598 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.42143068

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(64, activation = 'relu')(x) 
x = Dropout(0.5)(x)
x = Dense(32, activation = 'relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                1605696
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 21,632,259
# Trainable params: 1,607,875
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_flair_frontal.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer_history.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', verbose = 1, patience = 15)

# %%
# Compile model
model.compile(Adam(lr = 1e-5), 
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 30 
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/30
# 94/94 [==============================] - 15s 159ms/step - loss: 1.2299 - accuracy: 0.3175 - val_loss: 1.0764 - val_accuracy: 0.3912
#
# Epoch 00001: val_accuracy improved from -inf to 0.39123, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 2/30
# 94/94 [==============================] - 15s 156ms/step - loss: 1.0741 - accuracy: 0.3945 - val_loss: 1.0631 - val_accuracy: 0.4964
#
# Epoch 00002: val_accuracy improved from 0.39123 to 0.49639, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 3/30
# 94/94 [==============================] - 15s 156ms/step - loss: 1.0432 - accuracy: 0.4361 - val_loss: 1.0253 - val_accuracy: 0.5240
#
# Epoch 00003: val_accuracy improved from 0.49639 to 0.52404, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 4/30
# 94/94 [==============================] - 15s 155ms/step - loss: 1.0129 - accuracy: 0.4838 - val_loss: 0.9927 - val_accuracy: 0.5451
#
# Epoch 00004: val_accuracy improved from 0.52404 to 0.54507, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 5/30
# 94/94 [==============================] - 15s 156ms/step - loss: 1.0092 - accuracy: 0.4954 - val_loss: 0.9834 - val_accuracy: 0.5541
#
# Epoch 00005: val_accuracy improved from 0.54507 to 0.55409, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 6/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.9821 - accuracy: 0.5168 - val_loss: 0.9624 - val_accuracy: 0.5667
#
# Epoch 00006: val_accuracy improved from 0.55409 to 0.56671, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 7/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.9579 - accuracy: 0.5278 - val_loss: 0.9588 - val_accuracy: 0.5925
#
# Epoch 00007: val_accuracy improved from 0.56671 to 0.59255, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 8/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.9491 - accuracy: 0.5474 - val_loss: 0.9489 - val_accuracy: 0.5877
#
# Epoch 00008: val_accuracy did not improve from 0.59255
# Epoch 9/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.9282 - accuracy: 0.5644 - val_loss: 0.9528 - val_accuracy: 0.5817
#
# Epoch 00009: val_accuracy did not improve from 0.59255
# Epoch 10/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.9228 - accuracy: 0.5765 - val_loss: 0.9363 - val_accuracy: 0.5931
#
# Epoch 00010: val_accuracy improved from 0.59255 to 0.59315, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 11/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.9065 - accuracy: 0.5731 - val_loss: 0.9260 - val_accuracy: 0.6010
#
# Epoch 00011: val_accuracy improved from 0.59315 to 0.60096, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 12/30
# 94/94 [==============================] - 15s 157ms/step - loss: 0.9084 - accuracy: 0.5819 - val_loss: 0.9191 - val_accuracy: 0.5950
#
# Epoch 00012: val_accuracy did not improve from 0.60096
# Epoch 13/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.8819 - accuracy: 0.6000 - val_loss: 0.9168 - val_accuracy: 0.6028
#
# Epoch 00013: val_accuracy improved from 0.60096 to 0.60276, saving model to /local/data1/elech646/code/train_logs/vgg19_flair_frontal_transfer.h5
# Epoch 14/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.8694 - accuracy: 0.6018 - val_loss: 0.9051 - val_accuracy: 0.5805
#
# Epoch 00014: val_accuracy did not improve from 0.60276
# Epoch 15/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.8648 - accuracy: 0.6122 - val_loss: 0.9047 - val_accuracy: 0.5992
#
# Epoch 00015: val_accuracy did not improve from 0.60276
# Epoch 16/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.8567 - accuracy: 0.6225 - val_loss: 0.8978 - val_accuracy: 0.5938
#
# Epoch 00016: val_accuracy did not improve from 0.60276
# Epoch 17/30
# 94/94 [==============================] - 15s 157ms/step - loss: 0.8297 - accuracy: 0.6337 - val_loss: 0.8989 - val_accuracy: 0.5968
#
# Epoch 00017: val_accuracy did not improve from 0.60276
# Epoch 18/30
# 94/94 [==============================] - 16s 169ms/step - loss: 0.8387 - accuracy: 0.6309 - val_loss: 0.8832 - val_accuracy: 0.5835
#
# Epoch 00018: val_accuracy did not improve from 0.60276
# Epoch 19/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.8152 - accuracy: 0.6449 - val_loss: 0.9071 - val_accuracy: 0.5925
#
# Epoch 00019: val_accuracy did not improve from 0.60276
# Epoch 20/30
# 94/94 [==============================] - 14s 153ms/step - loss: 0.8153 - accuracy: 0.6504 - val_loss: 0.9091 - val_accuracy: 0.6016
#
# Epoch 00020: val_accuracy did not improve from 0.60276
# Epoch 21/30
# 94/94 [==============================] - 15s 154ms/step - loss: 0.8043 - accuracy: 0.6582 - val_loss: 0.8984 - val_accuracy: 0.5962
#
# Epoch 00021: val_accuracy did not improve from 0.60276
# Epoch 22/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.8099 - accuracy: 0.6508 - val_loss: 0.9004 - val_accuracy: 0.5950
#
# Epoch 00022: val_accuracy did not improve from 0.60276
# Epoch 23/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.8188 - accuracy: 0.6430 - val_loss: 0.8999 - val_accuracy: 0.5950
#
# Epoch 00023: val_accuracy did not improve from 0.60276
# Epoch 24/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.8202 - accuracy: 0.6430 - val_loss: 0.9004 - val_accuracy: 0.5980
#
# Epoch 00024: val_accuracy did not improve from 0.60276
# Epoch 25/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.7976 - accuracy: 0.6678 - val_loss: 0.8978 - val_accuracy: 0.5950
#
# Epoch 00025: val_accuracy did not improve from 0.60276
# Epoch 26/30
# 94/94 [==============================] - 15s 154ms/step - loss: 0.7998 - accuracy: 0.6538 - val_loss: 0.9026 - val_accuracy: 0.5938
#
# Epoch 00026: val_accuracy did not improve from 0.60276
# Epoch 27/30
# 94/94 [==============================] - 15s 155ms/step - loss: 0.7874 - accuracy: 0.6585 - val_loss: 0.9019 - val_accuracy: 0.5956
#
# Epoch 00027: val_accuracy did not improve from 0.60276
# Epoch 28/30
# 94/94 [==============================] - 15s 156ms/step - loss: 0.7909 - accuracy: 0.6662 - val_loss: 0.9001 - val_accuracy: 0.5919
#
# Epoch 00028: val_accuracy did not improve from 0.60276
# Epoch 00028: early stopping
# Training took: 423.07 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(512, activation = 'relu')(x) # try 128, 64 the lower the better
#         x = Dropout(0.5)(x)
#         x = Dense(128, activation = 'relu')(x)
#         x = Dropout(0.5)(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 0.00001 with `ReduceLROnPlateau`
#
# training time: 1291s $\approx 22$ min
#
# test accuracy: 0.6250
#
# ------------------------------------------------------------------------------------------------------------------
#
# 2nd training:
#
# data augmentation: `brightness_range = [0.5, 2]`
#
# Setup: `x = vgg_19.output
#         x = Flatten()(x)
#         x = Dense(64, activation = 'relu')(x)
#         x = Dropout(0.5)(x)
#         x = Dense(32, activation = 'relu')(x)
#         x = Dropout(0.5)(x)
#         predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 423.07 s $\approx 7$ min
#
# test accuracy: 0.6406

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.8323
# Test accuracy: 0.6406

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

# for fancy LaTeX style plots
from matplotlib import rc
import matplotlib.pylab as plt

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex = True)

# Plot accuracy
plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('1st training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.savefig('VGG19_1st_training_flair_frontal_acc.png', dpi = 300)
plt.show()

# Plot loss
plt.plot(n_epochs, loss, label = 'Training loss')
plt.plot(n_epochs, val_loss, label = 'Validation loss')
plt.title('1st training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'best')
plt.savefig('VGG19_1st_training_flair_frontal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'PuBu')
for t in ax.texts: 
    t.set_text(t.get_text().replace('%', '\%'))
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
plt.savefig('VGG19_1st_training_CM_flair_frontal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
clsf_report.to_csv('Classification Report-1st Training on flair frontal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.04      0.05        97
#            1       0.62      0.53      0.57       207
#            2       0.78      0.93      0.85       294
#
#     accuracy                           0.65       598
#    macro avg       0.49      0.50      0.49       598
# weighted avg       0.61      0.65      0.62       598
