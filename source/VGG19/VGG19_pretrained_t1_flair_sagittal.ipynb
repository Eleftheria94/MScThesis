# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
# import tensorflow_addons as tfa
# from tensorflow_addons.optimizers import Lookahead
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import numpy as np
import os
import warnings
import pydot as pyd
import seaborn as sns
import pandas as pd
from timeit import default_timer as timer
import matplotlib.pyplot as plt

warnings.simplefilter(action = 'ignore', category = FutureWarning)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";

# GPUid to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
physical_devices # VICTORY
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Insert initial parameters
img_height, img_width = 224, 224
batch_size = 64
n_classes = 3

# Data augmentation
train_datagen = ImageDataGenerator(horizontal_flip = False, 
                                   vertical_flip = False,
                                   brightness_range = [0.5, 1.25],
                                   samplewise_center = True,
                                   rescale = 1./255)
#                                    preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(horizontal_flip = False, 
                                  vertical_flip = False,
                                  rotation_range = 0,
                                  samplewise_center = True,
                                  rescale = 1./255)
#                                   preprocessing_function = preprocess_input)

train = train_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/train', 
                                          classes = ['G2','G3','G4'], color_mode = 'rgb', 
                                          class_mode = 'categorical', 
                                          target_size = (img_height, img_width), 
                                          batch_size = batch_size, seed = 123)
validation = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/val', 
                                              classes = ['G2','G3','G4'], color_mode = 'rgb',
                                              class_mode = 'categorical', 
                                              target_size = (img_height, img_width), 
                                              batch_size = batch_size, seed = 123)
test = test_datagen.flow_from_directory('/local/data1/elech646/Tumor_grade_classification/dataset224_t1_flair_sagittal/test', 
                                        classes = ['G2','G3','G4'], color_mode = 'rgb',
                                        shuffle = False, class_mode = 'categorical', 
                                        target_size = (img_height, img_width), 
                                        batch_size = batch_size)
# Out:
# Found 8887 images belonging to 3 classes.
# Found 2584 images belonging to 3 classes.
# Found 647 images belonging to 3 classes.

# %%
# Use class weights
class_weights = class_weight.compute_class_weight(class_weight = 'balanced', 
                                                  classes = np.unique(train.classes), 
                                                  y = train.classes)

# Convert to dictionary
class_weights = dict(enumerate(class_weights))

# %%
x_train, y_train = next(iter(train))
print(x_train.shape, y_train.shape)
print(x_train.min())

# Plot the images for fun
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize = (20, 20))
    axes = axes.flatten()
    for img, ax in enumerate(axes):
        ax.imshow(images[img,:,:], cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train[:1000])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (64, 224, 224, 3) (64, 3)
# -0.35956404

# %%
# Load base model
vgg_19 = VGG19(input_shape = (224, 224, 3), weights = 'imagenet', include_top = False)

freeze_until_layer = 100

# Freeze all layers before the `freeze_until_layer` layer
for layer in vgg_19.layers[:freeze_until_layer]:
    layer.trainable = False

x = vgg_19.output
x = Flatten()(x)
x = Dense(50, activation = 'relu')(x)
x = Dropout(0.2)(x)
x = Dense(20, activation = 'relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(n_classes, activation = 'softmax')(x)

model = Model(inputs = vgg_19.input, outputs = predictions)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                1254450
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 21,279,917
# Trainable params: 1,255,533
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model, to_file = 'vgg19_plot_sagittal_t1_t1ce_2nd.png', show_shapes = True, show_layer_names = True)

# %%
# Save best model
checkpoint_path = '/local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                                monitor = 'val_accuracy',
                                                mode = 'max',
                                                verbose = 1,
                                                save_best_only = True)

# Save log for history
# append: True: append if file exists (useful for continuing training)
#         False: overwrite existing file
csv_logger = CSVLogger('/local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer_history.log', 
                       separator = ',', append = True)

# Reduce learning rate if val_accuracy is not improving
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.1,
                              patience = 5, min_lr = 0.000001)

es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience = 15, restore_best_weights = True)

# %%
# Compile model
model.compile(Adam(lr = 1e-5),   
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])   

epochs = 30 
batch_size = 64
start = timer()

history = model.fit(train, steps_per_epoch = len(train.labels) // batch_size, verbose = 1,
                    epochs = epochs, validation_data = validation,
                    validation_steps = len(validation.labels) // batch_size,
                    class_weight = class_weights,
                    callbacks = [es, reduce_lr, checkpoint, csv_logger])
# maybe add argument use_multiprocessing = True

end = timer()
print("Training took: %.2f s\n" % (end - start))
# Out:
# Epoch 1/30
# 138/138 [==============================] - 23s 161ms/step - loss: 1.1202 - accuracy: 0.4002 - val_loss: 0.9451 - val_accuracy: 0.6469
#
# Epoch 00001: val_accuracy improved from -inf to 0.64688, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 2/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.9936 - accuracy: 0.5497 - val_loss: 0.8841 - val_accuracy: 0.6352
#
# Epoch 00002: val_accuracy did not improve from 0.64688
# Epoch 3/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.9585 - accuracy: 0.5778 - val_loss: 0.8724 - val_accuracy: 0.6531
#
# Epoch 00003: val_accuracy improved from 0.64688 to 0.65312, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 4/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.9036 - accuracy: 0.6213 - val_loss: 0.8276 - val_accuracy: 0.6625
#
# Epoch 00004: val_accuracy improved from 0.65312 to 0.66250, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 5/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.8744 - accuracy: 0.6396 - val_loss: 0.8156 - val_accuracy: 0.6609
#
# Epoch 00005: val_accuracy did not improve from 0.66250
# Epoch 6/30
# 138/138 [==============================] - 22s 161ms/step - loss: 0.8350 - accuracy: 0.6572 - val_loss: 0.8133 - val_accuracy: 0.6625
#
# Epoch 00006: val_accuracy did not improve from 0.66250
# Epoch 7/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.8068 - accuracy: 0.6784 - val_loss: 0.7975 - val_accuracy: 0.6645
#
# Epoch 00007: val_accuracy improved from 0.66250 to 0.66445, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 8/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7971 - accuracy: 0.6817 - val_loss: 0.7907 - val_accuracy: 0.6594
#
# Epoch 00008: val_accuracy did not improve from 0.66445
# Epoch 9/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7713 - accuracy: 0.7068 - val_loss: 0.7730 - val_accuracy: 0.6746
#
# Epoch 00009: val_accuracy improved from 0.66445 to 0.67461, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 10/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.7516 - accuracy: 0.7151 - val_loss: 0.7738 - val_accuracy: 0.6734
#
# Epoch 00010: val_accuracy did not improve from 0.67461
# Epoch 11/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.7113 - accuracy: 0.7325 - val_loss: 0.7608 - val_accuracy: 0.6781
#
# Epoch 00011: val_accuracy improved from 0.67461 to 0.67813, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 12/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.6979 - accuracy: 0.7430 - val_loss: 0.7543 - val_accuracy: 0.6719
#
# Epoch 00012: val_accuracy did not improve from 0.67813
# Epoch 13/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.6934 - accuracy: 0.7451 - val_loss: 0.7602 - val_accuracy: 0.6691
#
# Epoch 00013: val_accuracy did not improve from 0.67813
# Epoch 14/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.6583 - accuracy: 0.7742 - val_loss: 0.7544 - val_accuracy: 0.6820
#
# Epoch 00014: val_accuracy improved from 0.67813 to 0.68203, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 15/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.6498 - accuracy: 0.7705 - val_loss: 0.7524 - val_accuracy: 0.6797
#
# Epoch 00015: val_accuracy did not improve from 0.68203
# Epoch 16/30
# 138/138 [==============================] - 22s 162ms/step - loss: 0.6467 - accuracy: 0.7686 - val_loss: 0.7426 - val_accuracy: 0.6797
#
# Epoch 00016: val_accuracy did not improve from 0.68203
# Epoch 17/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.6186 - accuracy: 0.7858 - val_loss: 0.7267 - val_accuracy: 0.6844
#
# Epoch 00017: val_accuracy improved from 0.68203 to 0.68437, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 18/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.6020 - accuracy: 0.7888 - val_loss: 0.7322 - val_accuracy: 0.6816
#
# Epoch 00018: val_accuracy did not improve from 0.68437
# Epoch 19/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.5952 - accuracy: 0.7924 - val_loss: 0.7373 - val_accuracy: 0.6832
#
# Epoch 00019: val_accuracy did not improve from 0.68437
# Epoch 20/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.5840 - accuracy: 0.8095 - val_loss: 0.7435 - val_accuracy: 0.6766
#
# Epoch 00020: val_accuracy did not improve from 0.68437
# Epoch 21/30
# 138/138 [==============================] - 22s 162ms/step - loss: 0.5654 - accuracy: 0.8031 - val_loss: 0.7438 - val_accuracy: 0.6777
#
# Epoch 00021: val_accuracy did not improve from 0.68437
# Epoch 22/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.5570 - accuracy: 0.8143 - val_loss: 0.7346 - val_accuracy: 0.6879
#
# Epoch 00022: val_accuracy improved from 0.68437 to 0.68789, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 23/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.5424 - accuracy: 0.8192 - val_loss: 0.7316 - val_accuracy: 0.6812
#
# Epoch 00023: val_accuracy did not improve from 0.68789
# Epoch 24/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.5496 - accuracy: 0.8109 - val_loss: 0.7320 - val_accuracy: 0.6828
#
# Epoch 00024: val_accuracy did not improve from 0.68789
# Epoch 25/30
# 138/138 [==============================] - 23s 167ms/step - loss: 0.5142 - accuracy: 0.8263 - val_loss: 0.7249 - val_accuracy: 0.6828
#
# Epoch 00025: val_accuracy did not improve from 0.68789
# Epoch 26/30
# 138/138 [==============================] - 22s 159ms/step - loss: 0.5127 - accuracy: 0.8358 - val_loss: 0.7141 - val_accuracy: 0.6859
#
# Epoch 00026: val_accuracy did not improve from 0.68789
# Epoch 27/30
# 138/138 [==============================] - 22s 158ms/step - loss: 0.5078 - accuracy: 0.8331 - val_loss: 0.7207 - val_accuracy: 0.6863
#
# Epoch 00027: val_accuracy did not improve from 0.68789
# Epoch 28/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.4901 - accuracy: 0.8374 - val_loss: 0.7185 - val_accuracy: 0.6891
#
# Epoch 00028: val_accuracy improved from 0.68789 to 0.68906, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 29/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.4883 - accuracy: 0.8448 - val_loss: 0.7134 - val_accuracy: 0.6906
#
# Epoch 00029: val_accuracy improved from 0.68906 to 0.69063, saving model to /local/data1/elech646/code/train_logs/vgg19_t1_flair_sagittal_transfer.h5
# Epoch 30/30
# 138/138 [==============================] - 22s 160ms/step - loss: 0.5006 - accuracy: 0.8380 - val_loss: 0.7188 - val_accuracy: 0.6875
#
# Epoch 00030: val_accuracy did not improve from 0.69063
# Training took: 675.04 s

# %% [markdown]
# 1st training:
#
# Setup: `x = vgg_19.output
#          x = Flatten()(x)
#          x = Dense(50, activation = 'relu')(x)
#          x = Dense(20, activation = 'relu')(x)
#          predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 128
#
# number of epochs = 40
#
# learning rate = 1e-5 with `ReduceLROnPlateau`
#
# training time: 1382.22 s $\approx 23$ min
#
# test accuracy: 0.6313 overfit
#
# ------------------------------------------------------------------------------------------------------------------
# 2nd training
#
# Setup : `x = vgg_19.output
#          x = Flatten()(x)
#          x = Dense(50, activation = 'relu')(x)
#          x = Dropout(0.2)(x)
#          x = Dense(20, activation = 'relu')(x)
#          x = Dropout(0.2)(x)
#          predictions = Dense(n_classes, activation = 'softmax')(x)`
#
# batch size = 64
#
# number of epochs = 30
#
# learning rate = 1e-5 with `ReduceLROnPlateau` + `EarlyStopping`
#
# training time: 1382.22 s $\approx 23$ min
#
# test accuracy: 71.56% (overfitting but there was continuous learning)

# %%
print(len(train.labels) // batch_size)

# %%
score = model.evaluate(test, steps = len(test.labels) // batch_size, verbose = 0)
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# Test loss: 0.6528
# Test accuracy: 0.7156

# %%
# Plot training + validation accuracy per epoch
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
n_epochs = range(len(acc))

plt.plot(n_epochs, acc, label = 'Training accuracy')
plt.plot(n_epochs, val_acc, label = 'Validation accuracy')
plt.title('2nd training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
#plt.savefig('VGG19_2nd_training_t1_flair_sagittal_acc.png', dpi = 300)
plt.show()

plt.plot(n_epochs, loss, label = 'Training accuracy')
plt.plot(n_epochs, val_loss, label = 'Validation accuracy')
plt.title('2nd training')
plt.xlabel('Epochs')
plt.ylabel('Cross-entropy')
plt.legend(loc = 'best')
#plt.savefig('VGG19_2nd_training_t1_flair_sagittal_loss.png', dpi = 300)
plt.show()

# %%
# Get rounded predictions
y_pred = np.argmax(model.predict(test), axis = 1) 

# Get true labels
y_true = test.classes

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)

#ax = sns.heatmap(cm, annot = True, cmap = 'Blues')
ax = sns.heatmap(cm / np.sum(cm), annot = True, fmt = '.2%', cmap = 'Blues')
ax.set_xlabel('\nPredicted values')
ax.set_ylabel('Actual values ');
# list must be in alphabetical order
ax.xaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
ax.yaxis.set_ticklabels(['Grade 2','Grade 3', 'Grade 4'])
#plt.savefig('2nd_Training_CM_t1_flair_sagittal.png', dpi = 300)
plt.show()

# %%
# Print classification report
print(classification_report(y_true, y_pred))

# Save the classification report
# clsf_report = pd.DataFrame(classification_report(y_true = y_true, y_pred = y_pred, output_dict = True)).transpose()
# clsf_report.to_csv('Classification Report-3rd Training on t1_flair sagittal.csv', index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.32      0.41       157
#            1       0.63      0.81      0.71       216
#            2       0.84      0.86      0.85       274
#
#     accuracy                           0.71       647
#    macro avg       0.68      0.66      0.66       647
# weighted avg       0.70      0.71      0.70       647
